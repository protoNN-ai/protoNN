# %%
import pandas
# %matplotlib inline
import matplotlib 
from protonn.stats import load_multiple_runs
matplotlib.style.use("dark_background")

# %%
experiments = load_multiple_runs("../data/chainer/runs/")

# %%
experiments[0].plot(x="elapsed_time", y="main/accuracy")

# %%
df = pandas.concat(experiments)
grouped = df.groupby("batch_size")
grouped.min().plot(y="epoch_time")
